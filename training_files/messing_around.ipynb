# %%
#first import libraries
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageFont, ImageEnhance
import os

#tensorflow
import tensorflow as tf
from tensorflow.python.keras.utils.vis_utils import plot_model

#import time
import time

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from PIL import Image, ImageEnhance, ImageOps
import matplotlib.pyplot as plt
import cv2
import random
import os

print("TensorFlow:", tf.__version__)
print("Devices:", tf.config.list_physical_devices())
# Out:
# TensorFlow: 2.20.0
# Devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
# !pip install ultralytics pillow matplotlib numpy opencv-python
# Out:
# Requirement already satisfied: ultralytics in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (8.4.14)
# Requirement already satisfied: pillow in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (12.1.0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (2.4.2)
# Requirement already satisfied: opencv-python in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (4.13.0.92)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from ultralytics) (1.17.0)
# Requirement already satisfied: torch>=1.8.0 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from ultralytics) (2.10.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from ultralytics) (0.25.0)
# Requirement already satisfied: psutil>=5.8.0 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from ultralytics) (1.38.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.38.1 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from polars>=0.20.0->ultralytics) (1.38.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2026.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/whereswaldo/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
from ultralytics import YOLO
import os
import numpy as np
from PIL import Image, ImageEnhance, ImageOps
import matplotlib.pyplot as plt
import random
import shutil

# %%
dataset_root = "waldo_dataset"

dirs = [
    f"{dataset_root}/images/train",
    f"{dataset_root}/images/val",
    f"{dataset_root}/labels/train",
    f"{dataset_root}/labels/val",
]

for d in dirs:
    os.makedirs(d, exist_ok=True)

print("Dataset folders created.")

# %%
#get the images directory
image_dir = os.getcwd() + '/images/finding_waldo'

#get the background and waldo image directory
background_dir = image_dir + '/wheres_wally.jpg'
waldo_dir = image_dir + '/waldo.png'



waldo_sprite = Image.open(waldo_dir).convert("RGBA")
bg_full = Image.open(background_dir).convert("RGB")
print("Assets loaded.")

# %%
IMG_W, IMG_H = 512, 512
WALDO_W, WALDO_H = 60, 100            # training Waldo size

waldo_resized = waldo_sprite.resize((WALDO_W, WALDO_H), Image.LANCZOS)

def jitter(im):
    im = ImageEnhance.Brightness(im).enhance(np.random.uniform(0.9, 1.1))
    im = ImageEnhance.Contrast(im).enhance(np.random.uniform(0.9, 1.1))
    if random.random() < 0.5:
        im = ImageOps.mirror(im)
    return im

def random_background_crop():
    # Simply resize the background to the training resolution.
    return bg_full.resize((IMG_W, IMG_H), Image.LANCZOS)

# %%
def make_synthetic_waldo(image_id, split="train"):
    bg = random_background_crop()
    bg = jitter(bg)

    # random paste position
    x = random.randint(0, IMG_W - WALDO_W)
    y = random.randint(0, IMG_H - WALDO_H)

    # paste Waldo
    bg.paste(waldo_resized, (x, y), waldo_resized)

    # YOLO normalized bounding box
    x_center = (x + WALDO_W/2) / IMG_W
    y_center = (y + WALDO_H/2) / IMG_H
    w_norm = WALDO_W / IMG_W
    h_norm = WALDO_H / IMG_H

    img_path = f"{dataset_root}/images/{split}/{image_id}.jpg"
    lbl_path = f"{dataset_root}/labels/{split}/{image_id}.txt"

    # save image
    bg.save(img_path)

    # save label (class 0 = Waldo)
    with open(lbl_path, "w") as f:
        f.write(f"0 {x_center} {y_center} {w_norm} {h_norm}\n")

    return img_path

# %%
yaml_text = f"""
path: {dataset_root}
train: images/train
val: images/val

names:
  0: waldo
"""

with open("waldo.yaml", "w") as f:
    f.write(yaml_text)

print("waldo.yaml created.")

# %%
model = YOLO("yolov8s.pt")  # you can switch to yolov8n.pt for faster training

model.train(
    data="waldo.yaml",
    epochs=30,
    imgsz=640,
    device="mps",      # uses Apple Metal GPU
)

# %%
trained = YOLO("runs/detect/train/weights/best.pt")

result = trained.predict(
    source="test_waldo_image.jpg",   # OR another image
    device="mps",
    save=True
)

result
# Out:
# image 1/1 /Users/scmmw/Library/CloudStorage/OneDrive-UniversityofLeeds/Documents/GitHub/FindWaldo/test_waldo_image.jpg: 480x640 1 waldo, 219.7ms
# Speed: 4.1ms preprocess, 219.7ms inference, 32.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /Users/scmmw/Library/CloudStorage/OneDrive-UniversityofLeeds/Documents/GitHub/FindWaldo/runs/detect/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'waldo'}
#  obb: None
#  orig_img: array([[[245, 230, 174],
#          [246, 230, 177],
#          [248, 231, 180],
#          ...,
#          [115, 100, 108],
#          [ 94,  79,  87],
#          [107,  92, 100]],
#
#         [[245, 229, 176],
#          [246, 230, 177],
#          [248, 231, 182],
#          ...,
#          [220, 206, 212],
#          [182, 167, 175],
#          [161, 147, 153]],
#
#         [[246, 227, 176],
#          [247, 227, 179],
#          [249, 229, 181],
#          ...,
#          [196, 182, 186],
#          [173, 159, 165],
#          [162, 148, 152]],
#
#         ...,
#
#         [[140, 188, 206],
#          [ 87, 132, 153],
#          [156, 194, 218],
#          ...,
#          [255, 255, 193],
#          [255, 255, 190],
#          [255, 251, 187]],
#
#         [[178, 228, 248],
#          [ 88, 135, 156],
#          [136, 177, 200],
#          ...,
#          [255, 250, 177],
#          [255, 255, 194],
#          [255, 255, 193]],
#
#         [[194, 245, 255],
#          [104, 154, 174],
#          [118, 158, 183],
#          ...,
#          [226, 216, 146],
#          [254, 244, 180],
#          [255, 248, 188]]], shape=(358, 500, 3), dtype=uint8)
#  orig_shape: (358, 500)
#  path: '/Users/scmmw/Library/CloudStorage/OneDrive-UniversityofLeeds/Documents/GitHub/FindWaldo/test_waldo_image.jpg'
#  probs: None
#  save_dir: '/Users/scmmw/Library/CloudStorage/OneDrive-UniversityofLeeds/Documents/GitHub/FindWaldo/runs/detect/predict2'
#  speed: {'preprocess': 4.141291021369398, 'inference': 219.7161249932833, 'postprocess': 32.70041703945026}]
